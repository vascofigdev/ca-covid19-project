# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ### Carregar valores sobre o H1N1
# Carrega os dados gerais (casos confirmados e mortes por país) sobre a pandemia do h1n1 (na europa) e coloca-os numa tabela.

# %%
#Teste para a data do h1n1
#Infelizmente não há data praticamente nenhuma
url = 'https://en.wikipedia.org/wiki/2009_swine_flu_pandemic_in_Europe'
tables = pd.read_html(url)
h1n1 = tables[0]

h1n1.head(57)
h1n1= h1n1.dropna()
h1n1
# Out:
#                                               Country  \
#                                               Country
# 1                                               Total
# 2                                              Turkey
# 3                                              Russia
# 4                                      United Kingdom
# 5                                               Spain
# 6                                             Ukraine
# 7                                              France
# 8                                               Italy
# 9                                             Germany
# 10                                             Poland
# 11                                             Greece
# 12                                           Portugal
# 13                                        Netherlands
# 14                                             Serbia
# 15                                     Czech Republic
# ...

# %% [markdown]
# ### Carregar valores sobre o Covid19
# Carrega os dados sobre a pandemia do covid19 do mundo/europa

# %%
import pandas as pd
covid = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv")
covid = covid.drop(columns=['Province/State', 'Lat',"Long"])
covid.head()
covid
# Out:
#             Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0              Afghanistan        0        0        0        0        0
# 1                  Albania        0        0        0        0        0
# 2                  Algeria        0        0        0        0        0
# 3                  Andorra        0        0        0        0        0
# 4                   Angola        0        0        0        0        0
# ..                     ...      ...      ...      ...      ...      ...
# 259                 France        0        0        0        0        0
# 260            South Sudan        0        0        0        0        0
# 261         Western Sahara        0        0        0        0        0
# 262  Sao Tome and Principe        0        0        0        0        0
# 263                  Yemen        0        0        0        0        0
#
#      1/27/20  1/28/20  1/29/20  1/30/20  ...  4/20/20  4/21/20  4/22/20  \
# ...

# %% [markdown]
# Descobre a data do primeiro caso de cada país, e cria um gráfico com o crescimento do número de casos por pais, desde o primeiro caso

# %%
dic = {}
#acceptedCountries = ['Germany', 'Spain']
for row in covid.iloc:
    for i in range(1,100):
        if (row[i] != 0):
            dic[row[0]] = i
            break
            
#countries = df[ i in df['Country/Region'] && i == ["Portugal"] ].index
#dfObj.drop(indexNames , inplace=True)

# %% [markdown]
# Relaciona os dois gráficos, descobrindo quanto tempo levou cada país, desde o primeiro caso, a ultrapassar os números do H1N1
